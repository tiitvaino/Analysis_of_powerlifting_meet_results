# %%
import numpy as np
import pandas as pd
import datetime
from sklearn.utils import shuffle
# %matplotlib inline

# %%
df = pd.read_csv("Data/train_data.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PreviousComps', 'Sex', 'Equipment', 'Age', 'Wilks',
#        'Tested', 'Date', 'BodyweightKg'],
#       dtype='object')

# %%
pd.to_numeric(df['PreviousComps'], errors='coerce').hist(bins=139)
print(df.PreviousComps.describe())
# Out:
# count    255769.000000
# mean          4.915259
# std           7.052291
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           6.000000
# max         139.000000
# Name: PreviousComps, dtype: float64

# %%
df.Sex.value_counts().plot(kind="bar")
print(df.Sex.describe())
# Out:
# count    255769.000000
# mean          0.303387
# std           0.459722
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: Sex, dtype: float64

# %%
df.Equipment.value_counts().plot(kind="bar")
print(df.Equipment.describe())
# Out:
# count    255769.000000
# mean          0.436472
# std           0.495949
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: Equipment, dtype: float64

# %%
pd.to_numeric(df['Age'], errors='coerce').hist(bins=81)
print(df.Age.describe())
# Out:
# count    255769.000000
# mean         29.438341
# std          12.235231
# min          15.000000
# 25%          20.500000
# 50%          25.500000
# 75%          35.500000
# max          95.500000
# Name: Age, dtype: float64

# %%
pd.to_numeric(df['Wilks'], errors='coerce').hist(bins=40)
print(df.Wilks.describe())
# Out:
# count    255769.000000
# mean        371.905996
# std          81.704348
# min          39.580000
# 25%         315.820000
# 50%         367.670000
# 75%         424.490000
# max         691.800000
# Name: Wilks, dtype: float64

# %%
df.Tested.value_counts().plot(kind="bar")
print(df.Tested.describe())
# Out:
# count    255769.000000
# mean          0.827915
# std           0.377455
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: Tested, dtype: float64

# %%
df.Date.value_counts()
print(df.Date.describe())
# Out:
# count         255769
# unique          4187
# top       2019-02-09
# freq            1256
# Name: Date, dtype: object

# %%
pd.to_numeric(df['BodyweightKg'], errors='coerce').hist(bins=30)
df.BodyweightKg.describe()
# Out:
# count    255769.000000
# mean         82.865895
# std          22.058886
# min          24.950000
# 25%          66.400000
# 50%          81.100000
# 75%          96.450000
# max         242.400000
# Name: BodyweightKg, dtype: float64
